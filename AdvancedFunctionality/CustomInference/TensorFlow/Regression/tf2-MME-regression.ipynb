# %% [markdown]
# # Amazon SageMaker TensorFlow Custom Inference.py Tabular/Regression Example

# %% [markdown]
# <b>Notebook Setting</b>
# - Kernel: conda_tf2_p36
# - Notebook Instance: ml.c5.xlarge
#
# <b>Notebook Scope</b>
# - Dataset: Boston Housing Regression
# - Model Training with TF ANN script
# - Deployment with custom inference.py script for a tabular dataset

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import boto3
import sagemaker
import os
from sagemaker.tensorflow import TensorFlow
from sagemaker.inputs import TrainingInput
from sagemaker import get_execution_role
from sagemaker.tensorflow.serving import TensorFlowModel

# %% [markdown]
# ## Role and S3 Buckets

# %%
role = get_execution_role()
session = boto3.Session()
sagemaker_session = sagemaker.Session()

s3 = session.resource('s3')
TF_FRAMEWORK_VERSION = '2.3.0' #adjust for your version
BUCKET = sagemaker.Session().default_bucket()
PREFIX = 'regression-models'

# %% [markdown]
# # Boston Housing Model Training

# %% [markdown]
# ## Boston Dataset Creation

# %%
from sklearn import datasets #Boston Housing
boston = datasets.load_boston()
X = pd.DataFrame(boston.data, columns=boston.feature_names)
y = pd.DataFrame(boston.target)
y.columns=['TARGET']
df = pd.concat([X,y], axis=1)

#split into train and test to push to local
bostonTrain = df.iloc[:450,:]
bostonTest = df.iloc[451:,:]

# %%
DATASET_PATH = './Data/Boston'
os.makedirs(DATASET_PATH, exist_ok=True)

# %%
bostonTrain.to_csv('Data/Boston/train.csv', index=False)
bostonTest.to_csv('Data/Boston/test.csv', index=False)

# %%
# !aws s3 cp ./{DATASET_PATH}/train.csv s3://{BUCKET}/{PREFIX}/BostonHousing/train/
# Out:
# upload: Data/Boston/train.csv to s3://sagemaker-us-east-1-474422712127/regression-models/BostonHousing/train/train.csv

# %% [markdown]
# ## Create Training Inputs Boston Model

# %%
train_input = TrainingInput(s3_data=f's3://{BUCKET}/{PREFIX}/BostonHousing/train',content_type='csv')

# %%
inputs = {'train': train_input}

# %% [markdown]
# ## Boston Model Training

# %%
model_name = 'bostonhousing-ann'
hyperparameters = {'epochs': 50}
estimator_parameters = {'source_dir':"Scripts",
                        'entry_point':'boston.py',
                        'instance_type': 'ml.m5.2xlarge',
                        'instance_count': 1,
                        'model_dir': f'/opt/ml/model',
                        'role': role,
                        'hyperparameters': hyperparameters,
                        'output_path': f's3://{BUCKET}/{PREFIX}/BostonHousing/out',
                        'base_job_name': f'mme-cv-{model_name}',
                        'framework_version': TF_FRAMEWORK_VERSION,
                        'py_version': 'py37',
                        'script_mode': True}
estimator_1 = TensorFlow(**estimator_parameters)
estimator_1.fit(inputs)
# Out:
# 2021-11-15 23:53:39 Starting - Starting the training job...
# 2021-11-15 23:54:06 Starting - Launching requested ML instancesProfilerReport-1637020419: InProgress
# ......
# 2021-11-15 23:55:06 Starting - Preparing the instances for training.........
# 2021-11-15 23:56:26 Downloading - Downloading input data
# 2021-11-15 23:56:26 Training - Downloading the training image..2021-11-15 23:56:48,826 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-11-15 23:56:48,834 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-15 23:56:49,204 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-15 23:56:49,220 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-15 23:56:49,234 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-15 23:56:49,244 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "/opt/ml/model",
#         "epochs": 50
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "mme-cv-bostonhousing-ann-2021-11-15-23-53-39-073",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-474422712127/mme-cv-bostonhousing-ann-2021-11-15-23-53-39-073/source/sourcedir.tar.gz",
#     "module_name": "boston",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "boston.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":50,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=boston.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=boston
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-474422712127/mme-cv-bostonhousing-ann-2021-11-15-23-53-39-073/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":50,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"mme-cv-bostonhousing-ann-2021-11-15-23-53-39-073","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-474422712127/mme-cv-bostonhousing-ann-2021-11-15-23-53-39-073/source/sourcedir.tar.gz","module_name":"boston","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"boston.py"}
# SM_USER_ARGS=["--epochs","50","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=50
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 boston.py --epochs 50 --model_dir /opt/ml/model
# reading
# read
# [2021-11-15 23:56:51.957 ip-10-2-74-94.ec2.internal:27 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-11-15 23:56:51.958 ip-10-2-74-94.ec2.internal:27 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-11-15 23:56:51.958 ip-10-2-74-94.ec2.internal:27 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2021-11-15 23:56:51.958 ip-10-2-74-94.ec2.internal:27 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-11-15 23:56:52.085 ip-10-2-74-94.ec2.internal:27 INFO hook.py:398] Monitoring the collections: losses, metrics, sm_metrics
# Epoch 1/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 102.6562#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 23ms/step - loss: 96.2346 - val_loss: 100.9744
# Epoch 2/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 50.9443#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 83.6856 - val_loss: 87.6685
# Epoch 3/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 119.2282#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 78.9078 - val_loss: 84.5077
# Epoch 4/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 34.0900#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 5ms/step - loss: 75.4050 - val_loss: 88.4243
# Epoch 5/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 84.2096#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 78.1069 - val_loss: 74.6119
# Epoch 6/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 67.6725#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - ETA: 0s - loss: 72.3448#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 8ms/step - loss: 72.3448 - val_loss: 69.9298
# Epoch 7/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 81.0374#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 71.7342 - val_loss: 77.9920
# Epoch 8/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 30.4030#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 67.0347 - val_loss: 66.1344
# Epoch 9/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 66.5714#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 62.6384 - val_loss: 65.9821
# Epoch 10/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 92.4296#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 62.5759 - val_loss: 70.0486
# Epoch 11/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 44.7413#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 66.5770 - val_loss: 61.3078
# Epoch 12/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 87.3461#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 61.5679 - val_loss: 64.0379
# Epoch 13/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 37.7623#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 59.6551 - val_loss: 63.1861
# Epoch 14/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 70.4550#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 59.5469 - val_loss: 56.8728
# Epoch 15/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 120.6384#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 58.0055 - val_loss: 55.5782
# Epoch 16/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 57.4877#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 55.2229 - val_loss: 54.2239
# Epoch 17/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 66.2864#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 53.4388 - val_loss: 55.9881
# Epoch 18/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 54.4827#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 55.2431 - val_loss: 51.4947
# Epoch 19/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 79.0344#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 55.7815 - val_loss: 54.4866
# Epoch 20/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 90.4567#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 56.2737 - val_loss: 48.9194
# Epoch 21/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 40.8558#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 50.8196 - val_loss: 55.7817
# Epoch 22/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 78.1591#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 48.9707 - val_loss: 47.4253
# Epoch 23/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 67.5556#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 49.6131 - val_loss: 48.9144
# Epoch 24/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 78.4660#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 50.8605 - val_loss: 47.9731
# Epoch 25/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 54.4800#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 48.0467 - val_loss: 46.8671
# Epoch 26/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 44.0726#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 46.7840 - val_loss: 46.6467
# Epoch 27/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 41.4764#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 46.8129 - val_loss: 47.9718
# Epoch 28/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 48.2004#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 50.0405 - val_loss: 43.0578
# Epoch 29/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 41.9883#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 44.9241 - val_loss: 46.4870
# Epoch 30/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 56.2277#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 46.3700 - val_loss: 41.5124
# Epoch 31/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 39.8464#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 43.6310 - val_loss: 41.5553
# Epoch 32/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 47.5756#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 43.3755 - val_loss: 43.0629
# Epoch 33/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 21.9720#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 10ms/step - loss: 43.2636 - val_loss: 45.8823
# Epoch 34/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 72.0292#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 44.1611 - val_loss: 39.9809
# Epoch 35/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 82.0016#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 43.9589 - val_loss: 43.6572
# Epoch 36/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 38.9251#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 45.3320 - val_loss: 38.5388
# Epoch 37/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 12.1439#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 42.1554 - val_loss: 38.6437
# Epoch 38/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 28.4112#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 41.6217 - val_loss: 37.5188
# Epoch 39/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 41.0389#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 40.3327 - val_loss: 37.9871
# Epoch 40/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 33.4438#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 39.5966 - val_loss: 36.4961
# Epoch 41/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 40.0179#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 40.3428 - val_loss: 42.5306
# Epoch 42/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 28.2296#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 41.6786 - val_loss: 39.5710
# Epoch 43/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 40.1403#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 39.6128 - val_loss: 35.3340
# Epoch 44/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 56.9186#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 39.2193 - val_loss: 35.1493
# Epoch 45/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 26.4457#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 38.8734 - val_loss: 35.8708
# Epoch 46/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 25.1342#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 42.6458 - val_loss: 36.7812
# Epoch 47/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 29.2523#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01511/12 [==========================>...] - ETA: 0s - loss: 39.4369#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 8ms/step - loss: 39.4841 - val_loss: 36.6960
# Epoch 48/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 33.3680#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 38.3093 - val_loss: 33.5878
# Epoch 49/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 28.2143#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 6ms/step - loss: 38.9002 - val_loss: 35.9893
# Epoch 50/50
# #015 1/12 [=>............................] - ETA: 0s - loss: 22.6199#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01512/12 [==============================] - 0s 7ms/step - loss: 39.7615 - val_loss: 42.3453
# Saving model
#
# 2021-11-15 23:57:09 Uploading - Uploading generated training model
# 2021-11-15 23:57:09 Completed - Training job completed
# 2021-11-15 23:56:58,334 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 57
# Billable seconds: 57

# %% [markdown]
# ## Create Boston Model

# %%
model_1 = estimator_1.create_model(role=role, source_dir="Scripts", entry_point="inference.py")

# %% [markdown]
# ## Create Boston Endpoint

# %%
predictorA = model_1.deploy(
    initial_instance_count=1,
    instance_type="ml.c5.xlarge",
)
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ----!

# %% [markdown]
# ## Test Boston Endpoint

# %%
predictorA.serializer = sagemaker.serializers.JSONSerializer()
predictorA.deserializer = sagemaker.deserializers.JSONDeserializer()

# %%
#Grab sample test data
test = pd.read_csv('Data/Boston/train.csv')
test[:1]
testX = test.drop("TARGET", axis=1)
testX = testX[:1].values.tolist()
sampInput = {"inputs": testX}
sampInput
# Out:
# {'inputs': [[0.00632,
#    18.0,
#    2.31,
#    0.0,
#    0.5379999999999999,
#    6.575,
#    65.2,
#    4.09,
#    1.0,
#    296.0,
#    15.3,
#    396.9,
#    4.98]]}

# %%
predicted_value = predictorA.predict(sampInput)
predicted_value
# Out:
# {'outputs': [[35.0728226]]}

# %% [markdown]
# ## Boto3 Invocation

# %%
import boto3
import json
from sagemaker.serializers import JSONSerializer

runtime_sm_client = boto3.client(service_name='sagemaker-runtime')
endpoint_name = predictorA.endpoint_name
jsons = JSONSerializer()
payload = jsons.serialize(sampInput)
response = runtime_sm_client.invoke_endpoint(
        EndpointName=endpoint_name,
        Body=payload)
result = json.loads(response['Body'].read().decode())['outputs']
result
# Out:
# [[35.0728226]]

# %% [markdown]
# ## Delete Endpoint

# %%
predictorA.delete_endpoint(delete_endpoint_config=True)
